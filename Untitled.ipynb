# %%
"""def Get_Z (p_value) :
    return norm.ppf(1-p_value)
def Get_pValue (Z) :
    return 1. - norm.cdf(Z)
"""
# Out:
# 'def Get_Z (p_value) :\n    return norm.ppf(1-p_value)\ndef Get_pValue (Z) :\n    return 1. - norm.cdf(Z)\n'

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import ROOT
import itertools as it
import plotting as pl
# Out:
# Welcome to ROOTaaS 6.06/05

# %%
path = '/mnt/t3nfs01/data01/shome/jandrejk/higgs_model_dep/MoriondAnalysis/differential_recoMatrices/'
N_Pt_pred_BSM1 = np.load(path+'N_reco_pred_genPt_BSM1.npy')
N_Pt_pred_SM = np.load(path+'N_reco_pred_genPt_SM.npy')
N_Pt_true_BSM1 = np.load(path+'N_reco_true_genPt_BSM1.npy')
N_Pt_true_SM = np.load(path+'N_reco_true_genPt_SM.npy')

# %%
fig = plt.figure(figsize=(12,6))

ax1 = fig.add_subplot(141)
ax1.imshow(N_Pt_pred_BSM1,interpolation='nearest')
ax1.set_title('BSM1 pred')


ax2 = fig.add_subplot(142)
ax2.imshow(N_Pt_true_BSM1,interpolation='nearest')
ax2.set_title('BSM1 true')

ax3 = fig.add_subplot(143)
ax3.imshow(N_Pt_pred_SM,interpolation='nearest')
ax3.set_title('SM pred')

ax4 = fig.add_subplot(144)
ax4.imshow(N_Pt_true_SM,interpolation='nearest')
ax4.set_title('SM true')

plt.show()

# %%
"""
plt.imshow(N_Pt_pred_BSM1-N_Pt_true_BSM1,interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(N_Pt_pred_SM-N_Pt_true_SM,interpolation='nearest')
plt.colorbar()
plt.show()
"""
# Out:
# "\nplt.imshow(N_Pt_pred_BSM1-N_Pt_true_BSM1,interpolation='nearest')\nplt.colorbar()\nplt.show()\n\nplt.imshow(N_Pt_pred_SM-N_Pt_true_SM,interpolation='nearest')\nplt.colorbar()\nplt.show()\n"

# %%
print('relative difference between the number of predicted and true event in every genPt bin for the BSM1 sample')
print(np.sum(N_Pt_pred_BSM1,axis=0) / np.sum(N_Pt_true_BSM1,axis=0) -1.)
# Out:
# relative difference between the number of predicted and true event in every genPt bin for the BSM1 sample
# [  2.08372295e-07  -7.40933442e-08  -2.39714820e-07   1.34904888e-06
#   -4.28022224e-07   1.48388837e-06   6.52634071e-07   2.37604951e-08]

# %%
print('relative difference between the number of predicted and true event in every genPt bin for the SM sample')
print(np.sum(N_Pt_pred_SM,axis=0) / np.sum(N_Pt_true_SM,axis=0) -1.)
# Out:
# relative difference between the number of predicted and true event in every genPt bin for the SM sample
# [  2.64062041e-06   4.11614637e-06   1.83792392e-06   1.45463335e-06
#    2.50693519e-06   2.92070247e-06   3.03389096e-06   7.21456203e-07]

# %%
tb = ROOT.TBrowser()

# %%
f = ROOT.TFile("correlation_matrices/Datacard_13TeV_differential_pT_moriond17_reminiaod_extrabin_corrections_newsysts_v5_recoMuFit_covmat.root")

# %%
f.ls()
# Out:
# TFile**		correlation_matrices/Datacard_13TeV_differential_pT_moriond17_reminiaod_extrabin_corrections_newsysts_v5_recoMuFit_covmat.root
#  TFile*		correlation_matrices/Datacard_13TeV_differential_pT_moriond17_reminiaod_extrabin_corrections_newsysts_v5_recoMuFit_covmat.root
#   KEY: RooFitResult	fit;1
#   KEY: TProcessID	ProcessID0;1	1d0eb3ce-5104-11e7-9717-3d5bb8bcbeef

# %%
t = f.Get("fit")

# %%
t.correlation("r7_cat0","r7_cat0")
# Out:
# 1.0

# %%
NPtbins = 8
Ncat = 3

rho = np.zeros((Ncat*NPtbins,Ncat*NPtbins))
print np.shape(rho)

for i in it.product(range(Ncat),range(NPtbins)) :
    for j in it.product(range(Ncat),range(NPtbins)) :
        first = 'r'+str(i[1])+'_cat'+str(i[0])
        second = 'r'+str(j[1])+'_cat'+str(j[0])
        rho[NPtbins*i[0]+i[1],NPtbins*j[0]+j[1]] = t.correlation(first,second)
        #print first, second
# Out:
# (24, 24)

# %%
#print rho

# %%
plt.imshow(rho,interpolation='nearest')
plt.colorbar()
plt.show()

# %%
path = '/mnt/t3nfs01/data01/shome/jandrejk/higgs_model_dep/MoriondAnalysis/differential_recoMatrices/'
np.save(path+'RHO',rho)

# %%
sigma_mu = np.array([7.39e-01, 6.48e-01, 9.52e-01, 6.03e-01, 5.24e-01,
6.17e-01, 6.88e-01, 6.04e-01, 8.00e-01, 6.30e-01, 
5.45e-01, 8.00e-01, 6.64e-01, 6.29e-01, 7.03e-01,
5.40e-01, 5.74e-01, 6.14e-01, 5.19e-01, 6.15e-01, 
7.24e-01, 5.92e-01, 9.85e-01, 1.22e+00
                    ])
print sigma_mu
# Out:
# [ 0.739  0.648  0.952  0.603  0.524  0.617  0.688  0.604  0.8    0.63
#   0.545  0.8    0.664  0.629  0.703  0.54   0.574  0.614  0.519  0.615
#   0.724  0.592  0.985  1.22 ]

# %%
sigma_mu = pl.OrderPerCategory(array=sigma_mu,n=3)
print sigma_mu
# Out:
# [ 1.1085  0.945   0.7785  0.786   0.9435  1.4775  1.2     0.921   0.9045
#   0.996   0.888   0.906   0.861   1.428   1.2     1.086   1.032   0.81
#   0.972   0.8175  0.9225  0.9255  1.0545  1.83  ]

# %%
K_Pt_pred_BSM1 = N_Pt_pred_BSM1 / np.sum(N_Pt_pred_BSM1,axis=0)

# %%
print np.sum(K_Pt_pred_BSM1,axis=0)
# Out:
# [ 1.  1.  1.  1.  1.  1.  1.  1.]

# %% [markdown]
# # $$
# \lambda( \Delta \vec{\sigma}) \approx \chi^2 = \left(K \cdot \Delta \vec{\sigma} \mathcal{L}  - \vec{N}_{\mathrm{true}} \right)^{\mathrm{T}} C^{-1} \left(K \cdot \Delta \vec{\sigma} \mathcal{L} - \vec{N}_{\mathrm{true}} \right)
# $$

# %%
def chi2 (Delta_sigma, response, N_true, invCov,lumi=1.) :
    #print np.shape(np.dot(response,Delta_sigma))
    #print np.shape(N_true)
    vector = (np.dot(response,Delta_sigma)*lumi - N_true)
    return np.dot(vector.T,np.dot(invCov,vector))

# %%
def chi2_fixOneComp (Delta_sigma, response, N_true, invCov,fixed,lumi=1.) :
    #print fixed
    #print 'before: ', Delta_sigma
    pos = fixed[0]
    value = fixed[1]
    Delta_sigma[pos] = value
    #print 'after: ', Delta_sigma
    #print np.shape(np.dot(response,Delta_sigma))
    #print np.shape(N_true)
    vector = (np.dot(response,Delta_sigma)*lumi - N_true)
    return np.dot(vector.T,np.dot(invCov,vector))

# %%
def GetInverseCovariance (sigma_mu,N_true_SM,corr) :
    sigma_N = np.multiply(sigma_mu,N_true_SM)
    #C = np.tensordot(sigma_N.T,np.dot(corr,sigma_N))
    D_SigmaN = np.diag(sigma_N)
    C = np.dot(D_SigmaN.T,np.dot(corr,D_SigmaN))
    return np.linalg.inv(C)
    #return C

# %%
C_inv = GetInverseCovariance(sigma_mu=sigma_mu,
                            N_true_SM = np.sum(N_Pt_true_SM,axis=1)[1:],
                             corr=rho
                            )

# %%
print np.shape(C_inv)
#print C_inv
plt.imshow(C_inv,interpolation='nearest',origin='lower')
plt.colorbar()
plt.show()
# Out:
# (24, 24)

# %%
import scipy.optimize as opt

# %%
initial_guess = np.ones(len(np.sum(K_Pt_pred_BSM1,axis=0)))
print initial_guess
best_fit = opt.minimize(fun=chi2,
                       x0=initial_guess,
                       args=(K_Pt_pred_BSM1[1:,:], np.sum(N_Pt_true_BSM1,axis=1)[1:], C_inv),
                        method=None,
                        hess=C_inv
                       )
# Out:
# [ 1.  1.  1.  1.  1.  1.  1.  1.]

# %%
binwidth = [15,15,15,40,40,80,150,1000]
print 'best fit cross section: \n', best_fit.x
print np.sum(N_Pt_true_BSM1,axis=0) #/ np.array(binwidth)
#print best_fit
DeltaSigma_BF = best_fit.x
# Out:
# best fit cross section:
# [  15.06731622   42.5138876    58.25598525  149.9456541    91.56526184
#    65.72563317   18.10860975   -0.22388426]
# [  16.2679081    45.41390991   60.25055313  152.62919617   93.1448288
#    67.09667206   17.28836036    0.20578037]

# %%
"""plt.imshow(K_Pt_pred_BSM1,interpolation='nearest',origin='lower')
plt.show()
plt.imshow(K_Pt_pred_BSM1[1:,:],interpolation='nearest',origin='lower')
plt.show()"""
# Out:
# "plt.imshow(K_Pt_pred_BSM1,interpolation='nearest',origin='lower')\nplt.show()\nplt.imshow(K_Pt_pred_BSM1[1:,:],interpolation='nearest',origin='lower')\nplt.show()"

# %%
lambda_BF = chi2(Delta_sigma=DeltaSigma_BF,
           response=K_Pt_pred_BSM1[1:,:], #take out not-reco row 
           N_true=np.sum(N_Pt_true_BSM1,axis=1)[1:], 
           invCov=C_inv)
print lambda_BF
# Out:
# 73.2333204236

# %%
profiles = []
N_profiles = 2000
initial_guess = np.ones(len(np.sum(K_Pt_pred_BSM1,axis=0)))
for i,sigma_k in enumerate(DeltaSigma_BF) :
    sigma_k_range = np.linspace(0.5*sigma_k,1.5*sigma_k,N_profiles)
    lam_sigma = []
    for s in sigma_k_range :    
        optim = opt.minimize(fun=chi2_fixOneComp,
                               x0=initial_guess,
                               args=(K_Pt_pred_BSM1[1:,:], np.sum(N_Pt_true_BSM1,axis=1)[1:], C_inv, [i,s]),
                                method=None,
                                hess=C_inv
                               ) 
        lam_sigma.append(
            chi2(Delta_sigma=optim.x,
           response=K_Pt_pred_BSM1[1:,:], #take out not-reco row 
           N_true=np.sum(N_Pt_true_BSM1,axis=1)[1:], 
           invCov=C_inv)
        )
        """print i
        print s
        print (chi2(Delta_sigma=DeltaSigma_BF,
           response=K_Pt_pred_BSM1[1:,:], #take out not-reco row 
           N_true=np.sum(N_Pt_true_BSM1,axis=1)[1:], 
           invCov=C_inv)
               )
        #print optim.x
        print DeltaSigma_BF
        print optim.x
        print "---------"
        """
    #print lam_sigma
    profiles.append(lam_sigma)
    #print profiles
    #print '+++++++++++++++++++++++++++++++++++++'

# %%
yMax = 2.5
line_2p5 = np.zeros(N_profiles)+yMax
line_1 = np.zeros(N_profiles)+1.


sigma_fid_true = np.sum(N_Pt_true_BSM1,axis=0)

for i,sigma_k in enumerate(DeltaSigma_BF) :
    sigma_k_range = np.linspace(0.8*sigma_k,1.2*sigma_k,N_profiles)
    plt.plot(sigma_k_range,profiles[i]-lambda_BF,'k')
    plt.title('Likelihood scan'+'\n'+'scan over each x-sec in genPT while finding at each point the best fit for the others and evaluate the profile likelihood')
    plt.xlabel(r'fiducial corss section $\Delta \sigma$ for genpT bin '+str(i)+r' [$\mathrm{pb}$]' )
    plt.ylabel(r'$\lambda(\Delta \vec{\sigma})$')
    
    plt.ylim(0.,yMax)
    idx2 = np.argwhere(np.diff(np.sign(profiles[i]-lambda_BF - line_2p5)) != 0).reshape(-1) + 0
    idx1 = np.argwhere(np.diff(np.sign(profiles[i]-lambda_BF - line_1)) != 0).reshape(-1) + 0
    print sigma_k_range[idx1]
    plt.xlim(*sigma_k_range[idx2])
    plt.hlines(1.0,sigma_k_range[0],sigma_k_range[-1],color='k')
    plt.vlines(sigma_k_range[idx1][0],0.,np.array(profiles[i])[idx1]-lambda_BF)
    plt.vlines(sigma_k_range[idx1][1],0.,np.array(profiles[i])[idx1]-lambda_BF)
    
    print sigma_fid_true[i]
    #plt.vlines(sigma_fid_true[i],0.,yMax,'r')
    #plt.plot(sigma_k_range[idx1],np.array(profiles[i])[idx1]-lambda_BF, 'ro')
    plt.show()
# Out:
# [ 14.24272172  15.88889574]
# 16.2679080963
# [ 41.63340988  43.38585828]
# 45.4139099121
# [ 57.73724761  58.76306586]
# 60.2505531311
# [ 149.27056111  150.59074296]
# 152.629196167
# [ 91.28126753  91.83093393]
# 93.1448287964
# [ 65.42971986  66.00839477]
# 67.0966720581
# [ 17.98359784  18.22999813]
# 17.2883603573
# [-0.18730567 -0.26041804]
# 0.205780372024

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 1000)
f = np.arange(0, 1000)
g = np.sin(np.arange(0, 10, 0.01) * 2) * 1000

plt.plot(x, f, '-')
plt.plot(x, g, '-')

idx = np.argwhere(np.diff(np.sign(f - g)) != 0).reshape(-1) + 0
print x[idx]
plt.plot(x[idx], f[idx], 'ro')
plt.show()
# Out:
# [  0 149 331 448 664 743]
